# %%
# !cat container/Dockerfile
# Out:
# # Build an image that can do training and inference in SageMaker
# # This is a Python 3 image that uses the nginx, gunicorn, flask stack
# # for serving inferences in a stable way.
#
# FROM ubuntu:18.04
#
# MAINTAINER Amazon AI <sage-learner@amazon.com>
#
#
# RUN apt-get -y update && apt-get install -y --no-install-recommends \
#          wget \
#          python3-pip \
#          python3-setuptools \
#          nginx \
#          ca-certificates \
#     && rm -rf /var/lib/apt/lists/*
#
# RUN ln -s /usr/bin/python3 /usr/bin/python
# RUN ln -s /usr/bin/pip3 /usr/bin/pip
#
# # Here we get all python packages.
# # There's substantial overlap between scipy and numpy that we eliminate by
# # linking them together. Likewise, pip leaves the install caches populated which uses
# # a significant amount of space. These optimizations save a fair amount of space in the
# # image, which reduces start up time.
# RUN pip --no-cache-dir install numpy==1.16.2 scipy==1.2.1 scikit-learn==0.20.2 pandas flask gunicorn
#
# # Set some environment variables. PYTHONUNBUFFERED keeps Python from buffering our standard
# # output stream, which means that logs can be delivered to the user quickly. PYTHONDONTWRITEBYTECODE
# # keeps Python from writing the .pyc files which are unnecessary in this case. We also update
# # PATH so that the train and serve programs are found when the container is invoked.
#
# ENV PYTHONUNBUFFERED=TRUE
# ENV PYTHONDONTWRITEBYTECODE=TRUE
# ENV PATH="/opt/program:${PATH}"
#
# # Set up the program in the image
# COPY decision_trees /opt/program
# WORKDIR /opt/program

# %%
# %%sh
#
# # The name of our algorithm
# algorithm_name=sagemaker-decision-trees
#
# cd container
#
# chmod +x decision_trees/train
# chmod +x decision_trees/serve
#
# account=$(aws sts get-caller-identity --query Account --output text)
#
# # Get the region defined in the current configuration (default to us-west-2 if none defined)
# region=$(aws configure get region)
# region=${region:-us-west-2}
#
# fullname="${account}.dkr.ecr.${region}.amazonaws.com/${algorithm_name}:latest"
#
# # If the repository doesn't exist in ECR, create it.
# aws ecr describe-repositories --repository-names "${algorithm_name}" > /dev/null 2>&1
#
# if [ $? -ne 0 ]
# then
#     aws ecr create-repository --repository-name "${algorithm_name}" > /dev/null
# fi
#
# # Get the login command from ECR and execute it directly
# aws ecr get-login-password --region ${region}|docker login --username AWS --password-stdin ${fullname}
#
# # Build the docker image locally with the image name and then push it to ECR
# # with the full name.
#
# docker build -t ${algorithm_name} .
# docker tag ${algorithm_name} ${fullname}
#
# docker push ${fullname}
# Out:
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
# Login Succeeded
# #0 building with "default" instance using docker driver
#
# #1 [internal] load build definition from Dockerfile
# #1 transferring dockerfile:
# #1 transferring dockerfile: 1.56kB 0.0s done
# #1 DONE 0.1s
#
# #2 [internal] load metadata for docker.io/library/ubuntu:18.04
# #2 DONE 0.5s
#
# #3 [internal] load .dockerignore
# #3 transferring context: 2B done
# #3 DONE 0.0s
#
# #4 [internal] load build context
# #4 transferring context: 10.51kB done
# #4 DONE 0.0s
#
# #5 [1/7] FROM docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f07ca9127571cb9c29697f42acbfad72324b2bb2e43c98
# #5 resolve docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f07ca9127571cb9c29697f42acbfad72324b2bb2e43c98 0.0s done
# #5 sha256:152dc042452c496007f07ca9127571cb9c29697f42acbfad72324b2bb2e43c98 1.33kB / 1.33kB done
# #5 sha256:dca176c9663a7ba4c1f0e710986f5a25e672842963d95b960191e2d9f7185ebe 424B / 424B done
# #5 sha256:f9a80a55f492e823bf5d51f1bd5f87ea3eed1cb31788686aa99a2fb61a27af6a 2.30kB / 2.30kB done
# #5 sha256:7c457f213c7634afb95a0fb2410a74b7b5bc0ba527033362c240c7a11bef4331 0B / 25.69MB 0.1s
# #5 sha256:7c457f213c7634afb95a0fb2410a74b7b5bc0ba527033362c240c7a11bef4331 9.44MB / 25.69MB 0.2s
# #5 sha256:7c457f213c7634afb95a0fb2410a74b7b5bc0ba527033362c240c7a11bef4331 18.87MB / 25.69MB 0.3s
# #5 sha256:7c457f213c7634afb95a0fb2410a74b7b5bc0ba527033362c240c7a11bef4331 25.69MB / 25.69MB 0.4s
# #5 extracting sha256:7c457f213c7634afb95a0fb2410a74b7b5bc0ba527033362c240c7a11bef4331
# #5 sha256:7c457f213c7634afb95a0fb2410a74b7b5bc0ba527033362c240c7a11bef4331 25.69MB / 25.69MB 0.4s done
# #5 extracting sha256:7c457f213c7634afb95a0fb2410a74b7b5bc0ba527033362c240c7a11bef4331 2.2s done
# #5 DONE 2.7s
#
# #6 [2/7] RUN apt-get -y update && apt-get install -y --no-install-recommends          wget          python3-pip          python3-setuptools          nginx          ca-certificates     && rm -rf /var/lib/apt/lists/*
# #6 0.402 Get:1 http://archive.ubuntu.com/ubuntu bionic InRelease [242 kB]
# #6 0.531 Get:2 http://security.ubuntu.com/ubuntu bionic-security InRelease [102 kB]
# #6 0.539 Get:3 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [102 kB]
# #6 0.570 Get:4 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [102 kB]
# #6 0.697 Get:5 http://archive.ubuntu.com/ubuntu bionic/restricted amd64 Packages [13.5 kB]
# #6 0.753 Get:6 http://archive.ubuntu.com/ubuntu bionic/universe amd64 Packages [11.3 MB]
# #6 1.056 Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 Packages [1344 kB]
# #6 1.083 Get:8 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 Packages [186 kB]
# #6 1.088 Get:9 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2411 kB]
# #6 1.156 Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [3786 kB]
# #6 1.260 Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [30.8 kB]
# #6 1.263 Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [1728 kB]
# #6 1.267 Get:13 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1637 kB]
# #6 1.322 Get:14 http://archive.ubuntu.com/ubuntu bionic-backports/main amd64 Packages [64.0 kB]
# #6 1.324 Get:15 http://archive.ubuntu.com/ubuntu bionic-backports/universe amd64 Packages [20.6 kB]
# #6 1.744 Get:16 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [23.8 kB]
# #6 1.751 Get:17 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [3373 kB]
# #6 1.898 Get:18 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [1688 kB]
# #6 3.600 Fetched 28.2 MB in 3s (8693 kB/s)
# #6 3.600 Reading package lists...
# #6 5.467 Reading package lists...
# #6 7.167 Building dependency tree...
# #6 7.529 Reading state information...
# #6 7.871 The following additional packages will be installed:
# #6 7.876   fontconfig-config fonts-dejavu-core iproute2 libbsd0 libelf1 libexpat1
# #6 7.876   libfontconfig1 libfreetype6 libgd3 libgeoip1 libicu60 libjbig0
# #6 7.876   libjpeg-turbo8 libjpeg8 libmnl0 libmpdec2 libnginx-mod-http-geoip
# #6 7.876   libnginx-mod-http-image-filter libnginx-mod-http-xslt-filter
# #6 7.876   libnginx-mod-mail libnginx-mod-stream libpng16-16 libpsl5 libpython3-stdlib
# #6 7.876   libpython3.6-minimal libpython3.6-stdlib libreadline7 libsqlite3-0 libssl1.1
# #6 7.876   libtiff5 libwebp6 libx11-6 libx11-data libxau6 libxcb1 libxdmcp6 libxml2
# #6 7.876   libxpm4 libxslt1.1 mime-support multiarch-support nginx-common nginx-core
# #6 7.876   openssl python-pip-whl python3 python3-distutils python3-lib2to3
# #6 7.876   python3-minimal python3-pkg-resources python3.6 python3.6-minimal
# #6 7.876   readline-common ucf
# #6 7.878 Suggested packages:
# #6 7.878   iproute2-doc libgd-tools geoip-bin fcgiwrap nginx-doc ssl-cert python3-doc
# #6 7.878   python3-tk python3-venv python-setuptools-doc python3.6-venv python3.6-doc
# #6 7.878   binutils binfmt-support readline-doc
# #6 7.878 Recommended packages:
# #6 7.878   libatm1 libxtables12 geoip-database publicsuffix file xz-utils
# #6 7.878   build-essential python3-dev python3-wheel
# #6 8.219 The following NEW packages will be installed:
# #6 8.219   ca-certificates fontconfig-config fonts-dejavu-core iproute2 libbsd0 libelf1
# #6 8.220   libexpat1 libfontconfig1 libfreetype6 libgd3 libgeoip1 libicu60 libjbig0
# #6 8.220   libjpeg-turbo8 libjpeg8 libmnl0 libmpdec2 libnginx-mod-http-geoip
# #6 8.220   libnginx-mod-http-image-filter libnginx-mod-http-xslt-filter
# #6 8.220   libnginx-mod-mail libnginx-mod-stream libpng16-16 libpsl5 libpython3-stdlib
# #6 8.220   libpython3.6-minimal libpython3.6-stdlib libreadline7 libsqlite3-0 libssl1.1
# #6 8.220   libtiff5 libwebp6 libx11-6 libx11-data libxau6 libxcb1 libxdmcp6 libxml2
# #6 8.220   libxpm4 libxslt1.1 mime-support multiarch-support nginx nginx-common
# #6 8.221   nginx-core openssl python-pip-whl python3 python3-distutils python3-lib2to3
# #6 8.221   python3-minimal python3-pip python3-pkg-resources python3-setuptools
# #6 8.222   python3.6 python3.6-minimal readline-common ucf wget
# #6 8.430 0 upgraded, 59 newly installed, 0 to remove and 1 not upgraded.
# #6 8.430 Need to get 23.3 MB of archives.
# #6 8.430 After this operation, 88.7 MB of additional disk space will be used.
# #6 8.430 Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libssl1.1 amd64 1.1.1-1ubuntu2.1~18.04.23 [1303 kB]
# #6 9.131 Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpython3.6-minimal amd64 3.6.9-1~18.04ubuntu1.12 [533 kB]
# #6 9.155 Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libexpat1 amd64 2.2.5-3ubuntu0.9 [82.8 kB]
# #6 9.159 Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3.6-minimal amd64 3.6.9-1~18.04ubuntu1.12 [1609 kB]
# #6 9.263 Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3-minimal amd64 3.6.7-1~18.04 [23.7 kB]
# #6 9.268 Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 mime-support all 3.60ubuntu1 [30.1 kB]
# #6 9.269 Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmpdec2 amd64 2.4.2-1ubuntu1 [84.1 kB]
# #6 9.271 Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 readline-common all 7.0-3 [52.9 kB]
# #6 9.283 Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 libreadline7 amd64 7.0-3 [124 kB]
# #6 9.287 Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsqlite3-0 amd64 3.22.0-1ubuntu0.7 [499 kB]
# #6 9.297 Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpython3.6-stdlib amd64 3.6.9-1~18.04ubuntu1.12 [1713 kB]
# #6 9.343 Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3.6 amd64 3.6.9-1~18.04ubuntu1.12 [203 kB]
# #6 9.350 Get:13 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpython3-stdlib amd64 3.6.7-1~18.04 [7240 B]
# #6 9.399 Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3 amd64 3.6.7-1~18.04 [47.2 kB]
# #6 9.407 Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 multiarch-support amd64 2.27-3ubuntu1.6 [6960 B]
# #6 9.407 Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libjpeg-turbo8 amd64 1.5.2-0ubuntu5.18.04.6 [111 kB]
# #6 9.407 Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 openssl amd64 1.1.1-1ubuntu2.1~18.04.23 [614 kB]
# #6 9.423 Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 ca-certificates all 20230311ubuntu0.18.04.1 [151 kB]
# #6 9.429 Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libelf1 amd64 0.170-0.4ubuntu0.1 [44.8 kB]
# #6 9.430 Get:20 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmnl0 amd64 1.0.4-2 [12.3 kB]
# #6 9.488 Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 iproute2 amd64 4.15.0-2ubuntu1.3 [721 kB]
# #6 9.511 Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libbsd0 amd64 0.8.7-1ubuntu0.1 [41.6 kB]
# #6 9.515 Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libicu60 amd64 60.2-3ubuntu3.2 [8050 kB]
# #6 9.783 Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxml2 amd64 2.9.4+dfsg1-6.1ubuntu1.9 [663 kB]
# #6 9.802 Get:25 http://archive.ubuntu.com/ubuntu bionic/main amd64 ucf all 3.0038 [50.5 kB]
# #6 9.803 Get:26 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgeoip1 amd64 1.6.12-1 [71.8 kB]
# #6 9.805 Get:27 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpng16-16 amd64 1.6.34-1ubuntu0.18.04.2 [176 kB]
# #6 9.848 Get:28 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpsl5 amd64 0.19.1-5build1 [41.8 kB]
# #6 9.850 Get:29 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxau6 amd64 1:1.0.8-1ubuntu1 [7556 B]
# #6 9.850 Get:30 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxdmcp6 amd64 1:1.1.2-3 [10.7 kB]
# #6 9.855 Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb1 amd64 1.13-2~ubuntu18.04 [45.5 kB]
# #6 9.856 Get:32 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libx11-data all 2:1.6.4-3ubuntu0.4 [114 kB]
# #6 9.875 Get:33 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libx11-6 amd64 2:1.6.4-3ubuntu0.4 [572 kB]
# #6 9.964 Get:34 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 wget amd64 1.19.4-1ubuntu2.2 [316 kB]
# #6 9.992 Get:35 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-dejavu-core all 2.37-1 [1041 kB]
# #6 10.03 Get:36 http://archive.ubuntu.com/ubuntu bionic/main amd64 fontconfig-config all 2.12.6-0ubuntu2 [55.8 kB]
# #6 10.03 Get:37 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libfreetype6 amd64 2.8.1-2ubuntu2.2 [335 kB]
# #6 10.05 Get:38 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfontconfig1 amd64 2.12.6-0ubuntu2 [137 kB]
# #6 10.05 Get:39 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjpeg8 amd64 8c-2ubuntu8 [2194 B]
# #6 10.05 Get:40 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libjbig0 amd64 2.1-3.1ubuntu0.18.04.1 [27.0 kB]
# #6 10.05 Get:41 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libtiff5 amd64 4.0.9-5ubuntu0.10 [154 kB]
# #6 10.05 Get:42 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libwebp6 amd64 0.6.1-2ubuntu0.18.04.2 [186 kB]
# #6 10.06 Get:43 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxpm4 amd64 1:3.5.12-1ubuntu0.18.04.2 [34.8 kB]
# #6 10.14 Get:44 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgd3 amd64 2.2.5-4ubuntu0.5 [119 kB]
# #6 10.16 Get:45 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 nginx-common all 1.14.0-0ubuntu1.11 [37.2 kB]
# #6 10.17 Get:46 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libnginx-mod-http-geoip amd64 1.14.0-0ubuntu1.11 [11.0 kB]
# #6 10.17 Get:47 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libnginx-mod-http-image-filter amd64 1.14.0-0ubuntu1.11 [14.3 kB]
# #6 10.17 Get:48 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxslt1.1 amd64 1.1.29-5ubuntu0.3 [150 kB]
# #6 10.17 Get:49 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libnginx-mod-http-xslt-filter amd64 1.14.0-0ubuntu1.11 [12.8 kB]
# #6 10.17 Get:50 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libnginx-mod-mail amd64 1.14.0-0ubuntu1.11 [41.8 kB]
# #6 10.23 Get:51 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libnginx-mod-stream amd64 1.14.0-0ubuntu1.11 [63.5 kB]
# #6 10.24 Get:52 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 nginx-core amd64 1.14.0-0ubuntu1.11 [413 kB]
# #6 10.24 Get:53 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 nginx all 1.14.0-0ubuntu1.11 [3596 B]
# #6 10.32 Get:54 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 python-pip-whl all 9.0.1-2.3~ubuntu1.18.04.8 [1653 kB]
# #6 10.40 Get:55 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3-lib2to3 all 3.6.9-1~18.04 [77.4 kB]
# #6 10.41 Get:56 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3-distutils all 3.6.9-1~18.04 [144 kB]
# #6 10.41 Get:57 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 python3-pip all 9.0.1-2.3~ubuntu1.18.04.8 [114 kB]
# #6 10.41 Get:58 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3-pkg-resources all 39.0.1-2ubuntu0.1 [99.0 kB]
# #6 10.42 Get:59 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3-setuptools all 39.0.1-2ubuntu0.1 [248 kB]
# #6 10.59 debconf: delaying package configuration, since apt-utils is not installed
# #6 10.62 Fetched 23.3 MB in 2s (10.7 MB/s)
# #6 10.65 Selecting previously unselected package libssl1.1:amd64.
# (Reading database ... 4050 files and directories currently installed.)
# #6 10.66 Preparing to unpack .../libssl1.1_1.1.1-1ubuntu2.1~18.04.23_amd64.deb ...
# #6 10.66 Unpacking libssl1.1:amd64 (1.1.1-1ubuntu2.1~18.04.23) ...
# #6 10.81 Selecting previously unselected package libpython3.6-minimal:amd64.
# #6 10.81 Preparing to unpack .../libpython3.6-minimal_3.6.9-1~18.04ubuntu1.12_amd64.deb ...
# #6 10.83 Unpacking libpython3.6-minimal:amd64 (3.6.9-1~18.04ubuntu1.12) ...
# #6 11.02 Selecting previously unselected package libexpat1:amd64.
# #6 11.02 Preparing to unpack .../libexpat1_2.2.5-3ubuntu0.9_amd64.deb ...
# #6 11.02 Unpacking libexpat1:amd64 (2.2.5-3ubuntu0.9) ...
# #6 11.07 Selecting previously unselected package python3.6-minimal.
# #6 11.07 Preparing to unpack .../python3.6-minimal_3.6.9-1~18.04ubuntu1.12_amd64.deb ...
# #6 11.08 Unpacking python3.6-minimal (3.6.9-1~18.04ubuntu1.12) ...
# #6 11.49 Setting up libssl1.1:amd64 (1.1.1-1ubuntu2.1~18.04.23) ...
# #6 11.72 debconf: unable to initialize frontend: Dialog
# #6 11.72 debconf: (TERM is not set, so the dialog frontend is not usable.)
# #6 11.72 debconf: falling back to frontend: Readline
# #6 11.73 debconf: unable to initialize frontend: Readline
# #6 11.73 debconf: (Can't locate Term/ReadLine.pm in @INC (you may need to install the Term::ReadLine module) (@INC contains: /etc/perl /usr/local/lib/x86_64-linux-gnu/perl/5.26.1 /usr/local/share/perl/5.26.1 /usr/lib/x86_64-linux-gnu/perl5/5.26 /usr/share/perl5 /usr/lib/x86_64-linux-gnu/perl/5.26 /usr/share/perl/5.26 /usr/local/lib/site_perl /usr/lib/x86_64-linux-gnu/perl-base) at /usr/share/perl5/Debconf/FrontEnd/Readline.pm line 7.)
# #6 11.73 debconf: falling back to frontend: Teletype
# #6 11.78 Setting up libpython3.6-minimal:amd64 (3.6.9-1~18.04ubuntu1.12) ...
# #6 11.79 Setting up libexpat1:amd64 (2.2.5-3ubuntu0.9) ...
# #6 11.80 Setting up python3.6-minimal (3.6.9-1~18.04ubuntu1.12) ...
# #6 12.41 Selecting previously unselected package python3-minimal.
# (Reading database ... 4307 files and directories currently installed.)
# #6 12.43 Preparing to unpack .../0-python3-minimal_3.6.7-1~18.04_amd64.deb ...
# #6 12.43 Unpacking python3-minimal (3.6.7-1~18.04) ...
# #6 12.46 Selecting previously unselected package mime-support.
# #6 12.46 Preparing to unpack .../1-mime-support_3.60ubuntu1_all.deb ...
# #6 12.47 Unpacking mime-support (3.60ubuntu1) ...
# #6 12.50 Selecting previously unselected package libmpdec2:amd64.
# #6 12.50 Preparing to unpack .../2-libmpdec2_2.4.2-1ubuntu1_amd64.deb ...
# #6 12.51 Unpacking libmpdec2:amd64 (2.4.2-1ubuntu1) ...
# #6 12.57 Selecting previously unselected package readline-common.
# #6 12.58 Preparing to unpack .../3-readline-common_7.0-3_all.deb ...
# #6 12.59 Unpacking readline-common (7.0-3) ...
# #6 12.63 Selecting previously unselected package libreadline7:amd64.
# #6 12.63 Preparing to unpack .../4-libreadline7_7.0-3_amd64.deb ...
# #6 12.63 Unpacking libreadline7:amd64 (7.0-3) ...
# #6 12.70 Selecting previously unselected package libsqlite3-0:amd64.
# #6 12.70 Preparing to unpack .../5-libsqlite3-0_3.22.0-1ubuntu0.7_amd64.deb ...
# #6 12.71 Unpacking libsqlite3-0:amd64 (3.22.0-1ubuntu0.7) ...
# #6 12.80 Selecting previously unselected package libpython3.6-stdlib:amd64.
# #6 12.81 Preparing to unpack .../6-libpython3.6-stdlib_3.6.9-1~18.04ubuntu1.12_amd64.deb ...
# #6 12.81 Unpacking libpython3.6-stdlib:amd64 (3.6.9-1~18.04ubuntu1.12) ...
# #6 13.04 Selecting previously unselected package python3.6.
# #6 13.04 Preparing to unpack .../7-python3.6_3.6.9-1~18.04ubuntu1.12_amd64.deb ...
# #6 13.04 Unpacking python3.6 (3.6.9-1~18.04ubuntu1.12) ...
# #6 13.08 Selecting previously unselected package libpython3-stdlib:amd64.
# #6 13.08 Preparing to unpack .../8-libpython3-stdlib_3.6.7-1~18.04_amd64.deb ...
# #6 13.08 Unpacking libpython3-stdlib:amd64 (3.6.7-1~18.04) ...
# #6 13.10 Setting up python3-minimal (3.6.7-1~18.04) ...
# #6 13.44 Selecting previously unselected package python3.
# (Reading database ... 4765 files and directories currently installed.)
# #6 13.46 Preparing to unpack .../python3_3.6.7-1~18.04_amd64.deb ...
# #6 13.47 Unpacking python3 (3.6.7-1~18.04) ...
# #6 13.51 Selecting previously unselected package multiarch-support.
# #6 13.52 Preparing to unpack .../multiarch-support_2.27-3ubuntu1.6_amd64.deb ...
# #6 13.52 Unpacking multiarch-support (2.27-3ubuntu1.6) ...
# #6 13.66 Setting up multiarch-support (2.27-3ubuntu1.6) ...
# #6 13.72 Selecting previously unselected package libjpeg-turbo8:amd64.
# (Reading database ... 4802 files and directories currently installed.)
# #6 13.72 Preparing to unpack .../00-libjpeg-turbo8_1.5.2-0ubuntu5.18.04.6_amd64.deb ...
# #6 13.73 Unpacking libjpeg-turbo8:amd64 (1.5.2-0ubuntu5.18.04.6) ...
# #6 13.77 Selecting previously unselected package openssl.
# #6 13.77 Preparing to unpack .../01-openssl_1.1.1-1ubuntu2.1~18.04.23_amd64.deb ...
# #6 13.78 Unpacking openssl (1.1.1-1ubuntu2.1~18.04.23) ...
# #6 13.91 Selecting previously unselected package ca-certificates.
# #6 13.92 Preparing to unpack .../02-ca-certificates_20230311ubuntu0.18.04.1_all.deb ...
# #6 13.92 Unpacking ca-certificates (20230311ubuntu0.18.04.1) ...
# #6 14.00 Selecting previously unselected package libelf1:amd64.
# #6 14.00 Preparing to unpack .../03-libelf1_0.170-0.4ubuntu0.1_amd64.deb ...
# #6 14.01 Unpacking libelf1:amd64 (0.170-0.4ubuntu0.1) ...
# #6 14.05 Selecting previously unselected package libmnl0:amd64.
# #6 14.07 Preparing to unpack .../04-libmnl0_1.0.4-2_amd64.deb ...
# #6 14.08 Unpacking libmnl0:amd64 (1.0.4-2) ...
# #6 14.12 Selecting previously unselected package iproute2.
# #6 14.12 Preparing to unpack .../05-iproute2_4.15.0-2ubuntu1.3_amd64.deb ...
# #6 14.13 Unpacking iproute2 (4.15.0-2ubuntu1.3) ...
# #6 14.24 Selecting previously unselected package libbsd0:amd64.
# #6 14.25 Preparing to unpack .../06-libbsd0_0.8.7-1ubuntu0.1_amd64.deb ...
# #6 14.26 Unpacking libbsd0:amd64 (0.8.7-1ubuntu0.1) ...
# #6 14.29 Selecting previously unselected package libicu60:amd64.
# #6 14.29 Preparing to unpack .../07-libicu60_60.2-3ubuntu3.2_amd64.deb ...
# #6 14.29 Unpacking libicu60:amd64 (60.2-3ubuntu3.2) ...
# #6 15.30 Selecting previously unselected package libxml2:amd64.
# #6 15.30 Preparing to unpack .../08-libxml2_2.9.4+dfsg1-6.1ubuntu1.9_amd64.deb ...
# #6 15.31 Unpacking libxml2:amd64 (2.9.4+dfsg1-6.1ubuntu1.9) ...
# #6 15.43 Selecting previously unselected package ucf.
# #6 15.43 Preparing to unpack .../09-ucf_3.0038_all.deb ...
# #6 15.44 Moving old data out of the way
# #6 15.44 Unpacking ucf (3.0038) ...
# #6 15.47 Selecting previously unselected package libgeoip1:amd64.
# #6 15.47 Preparing to unpack .../10-libgeoip1_1.6.12-1_amd64.deb ...
# #6 15.47 Unpacking libgeoip1:amd64 (1.6.12-1) ...
# #6 15.50 Selecting previously unselected package libpng16-16:amd64.
# #6 15.50 Preparing to unpack .../11-libpng16-16_1.6.34-1ubuntu0.18.04.2_amd64.deb ...
# #6 15.50 Unpacking libpng16-16:amd64 (1.6.34-1ubuntu0.18.04.2) ...
# #6 15.56 Selecting previously unselected package libpsl5:amd64.
# #6 15.56 Preparing to unpack .../12-libpsl5_0.19.1-5build1_amd64.deb ...
# #6 15.57 Unpacking libpsl5:amd64 (0.19.1-5build1) ...
# #6 15.60 Selecting previously unselected package libxau6:amd64.
# #6 15.60 Preparing to unpack .../13-libxau6_1%3a1.0.8-1ubuntu1_amd64.deb ...
# #6 15.61 Unpacking libxau6:amd64 (1:1.0.8-1ubuntu1) ...
# #6 15.63 Selecting previously unselected package libxdmcp6:amd64.
# #6 15.63 Preparing to unpack .../14-libxdmcp6_1%3a1.1.2-3_amd64.deb ...
# #6 15.63 Unpacking libxdmcp6:amd64 (1:1.1.2-3) ...
# #6 15.66 Selecting previously unselected package libxcb1:amd64.
# #6 15.67 Preparing to unpack .../15-libxcb1_1.13-2~ubuntu18.04_amd64.deb ...
# #6 15.68 Unpacking libxcb1:amd64 (1.13-2~ubuntu18.04) ...
# #6 15.72 Selecting previously unselected package libx11-data.
# #6 15.72 Preparing to unpack .../16-libx11-data_2%3a1.6.4-3ubuntu0.4_all.deb ...
# #6 15.73 Unpacking libx11-data (2:1.6.4-3ubuntu0.4) ...
# #6 15.81 Selecting previously unselected package libx11-6:amd64.
# #6 15.82 Preparing to unpack .../17-libx11-6_2%3a1.6.4-3ubuntu0.4_amd64.deb ...
# #6 15.83 Unpacking libx11-6:amd64 (2:1.6.4-3ubuntu0.4) ...
# #6 15.91 Selecting previously unselected package wget.
# #6 15.91 Preparing to unpack .../18-wget_1.19.4-1ubuntu2.2_amd64.deb ...
# #6 15.92 Unpacking wget (1.19.4-1ubuntu2.2) ...
# #6 15.97 Selecting previously unselected package fonts-dejavu-core.
# #6 15.97 Preparing to unpack .../19-fonts-dejavu-core_2.37-1_all.deb ...
# #6 15.98 Unpacking fonts-dejavu-core (2.37-1) ...
# #6 16.11 Selecting previously unselected package fontconfig-config.
# #6 16.12 Preparing to unpack .../20-fontconfig-config_2.12.6-0ubuntu2_all.deb ...
# #6 16.12 Unpacking fontconfig-config (2.12.6-0ubuntu2) ...
# #6 16.15 Selecting previously unselected package libfreetype6:amd64.
# #6 16.16 Preparing to unpack .../21-libfreetype6_2.8.1-2ubuntu2.2_amd64.deb ...
# #6 16.16 Unpacking libfreetype6:amd64 (2.8.1-2ubuntu2.2) ...
# #6 16.22 Selecting previously unselected package libfontconfig1:amd64.
# #6 16.22 Preparing to unpack .../22-libfontconfig1_2.12.6-0ubuntu2_amd64.deb ...
# #6 16.23 Unpacking libfontconfig1:amd64 (2.12.6-0ubuntu2) ...
# #6 16.27 Selecting previously unselected package libjpeg8:amd64.
# #6 16.27 Preparing to unpack .../23-libjpeg8_8c-2ubuntu8_amd64.deb ...
# #6 16.27 Unpacking libjpeg8:amd64 (8c-2ubuntu8) ...
# #6 16.29 Selecting previously unselected package libjbig0:amd64.
# #6 16.30 Preparing to unpack .../24-libjbig0_2.1-3.1ubuntu0.18.04.1_amd64.deb ...
# #6 16.30 Unpacking libjbig0:amd64 (2.1-3.1ubuntu0.18.04.1) ...
# #6 16.32 Selecting previously unselected package libtiff5:amd64.
# #6 16.33 Preparing to unpack .../25-libtiff5_4.0.9-5ubuntu0.10_amd64.deb ...
# #6 16.34 Unpacking libtiff5:amd64 (4.0.9-5ubuntu0.10) ...
# #6 16.38 Selecting previously unselected package libwebp6:amd64.
# #6 16.39 Preparing to unpack .../26-libwebp6_0.6.1-2ubuntu0.18.04.2_amd64.deb ...
# #6 16.39 Unpacking libwebp6:amd64 (0.6.1-2ubuntu0.18.04.2) ...
# #6 16.43 Selecting previously unselected package libxpm4:amd64.
# #6 16.44 Preparing to unpack .../27-libxpm4_1%3a3.5.12-1ubuntu0.18.04.2_amd64.deb ...
# #6 16.44 Unpacking libxpm4:amd64 (1:3.5.12-1ubuntu0.18.04.2) ...
# #6 16.47 Selecting previously unselected package libgd3:amd64.
# #6 16.48 Preparing to unpack .../28-libgd3_2.2.5-4ubuntu0.5_amd64.deb ...
# #6 16.48 Unpacking libgd3:amd64 (2.2.5-4ubuntu0.5) ...
# #6 16.53 Selecting previously unselected package nginx-common.
# #6 16.53 Preparing to unpack .../29-nginx-common_1.14.0-0ubuntu1.11_all.deb ...
# #6 16.55 Unpacking nginx-common (1.14.0-0ubuntu1.11) ...
# #6 16.61 Selecting previously unselected package libnginx-mod-http-geoip.
# #6 16.62 Preparing to unpack .../30-libnginx-mod-http-geoip_1.14.0-0ubuntu1.11_amd64.deb ...
# #6 16.62 Unpacking libnginx-mod-http-geoip (1.14.0-0ubuntu1.11) ...
# #6 16.67 Selecting previously unselected package libnginx-mod-http-image-filter.
# #6 16.68 Preparing to unpack .../31-libnginx-mod-http-image-filter_1.14.0-0ubuntu1.11_amd64.deb ...
# #6 16.69 Unpacking libnginx-mod-http-image-filter (1.14.0-0ubuntu1.11) ...
# #6 16.73 Selecting previously unselected package libxslt1.1:amd64.
# #6 16.74 Preparing to unpack .../32-libxslt1.1_1.1.29-5ubuntu0.3_amd64.deb ...
# #6 16.74 Unpacking libxslt1.1:amd64 (1.1.29-5ubuntu0.3) ...
# #6 16.80 Selecting previously unselected package libnginx-mod-http-xslt-filter.
# #6 16.81 Preparing to unpack .../33-libnginx-mod-http-xslt-filter_1.14.0-0ubuntu1.11_amd64.deb ...
# #6 16.82 Unpacking libnginx-mod-http-xslt-filter (1.14.0-0ubuntu1.11) ...
# #6 16.86 Selecting previously unselected package libnginx-mod-mail.
# #6 16.86 Preparing to unpack .../34-libnginx-mod-mail_1.14.0-0ubuntu1.11_amd64.deb ...
# #6 16.87 Unpacking libnginx-mod-mail (1.14.0-0ubuntu1.11) ...
# #6 16.90 Selecting previously unselected package libnginx-mod-stream.
# #6 16.90 Preparing to unpack .../35-libnginx-mod-stream_1.14.0-0ubuntu1.11_amd64.deb ...
# #6 16.90 Unpacking libnginx-mod-stream (1.14.0-0ubuntu1.11) ...
# #6 16.94 Selecting previously unselected package nginx-core.
# #6 16.95 Preparing to unpack .../36-nginx-core_1.14.0-0ubuntu1.11_amd64.deb ...
# #6 16.95 Unpacking nginx-core (1.14.0-0ubuntu1.11) ...
# #6 17.01 Selecting previously unselected package nginx.
# #6 17.02 Preparing to unpack .../37-nginx_1.14.0-0ubuntu1.11_all.deb ...
# #6 17.02 Unpacking nginx (1.14.0-0ubuntu1.11) ...
# #6 17.07 Selecting previously unselected package python-pip-whl.
# #6 17.07 Preparing to unpack .../38-python-pip-whl_9.0.1-2.3~ubuntu1.18.04.8_all.deb ...
# #6 17.07 Unpacking python-pip-whl (9.0.1-2.3~ubuntu1.18.04.8) ...
# #6 17.27 Selecting previously unselected package python3-lib2to3.
# #6 17.28 Preparing to unpack .../39-python3-lib2to3_3.6.9-1~18.04_all.deb ...
# #6 17.28 Unpacking python3-lib2to3 (3.6.9-1~18.04) ...
# #6 17.34 Selecting previously unselected package python3-distutils.
# #6 17.34 Preparing to unpack .../40-python3-distutils_3.6.9-1~18.04_all.deb ...
# #6 17.34 Unpacking python3-distutils (3.6.9-1~18.04) ...
# #6 17.41 Selecting previously unselected package python3-pip.
# #6 17.44 Preparing to unpack .../41-python3-pip_9.0.1-2.3~ubuntu1.18.04.8_all.deb ...
# #6 17.45 Unpacking python3-pip (9.0.1-2.3~ubuntu1.18.04.8) ...
# #6 17.50 Selecting previously unselected package python3-pkg-resources.
# #6 17.50 Preparing to unpack .../42-python3-pkg-resources_39.0.1-2ubuntu0.1_all.deb ...
# #6 17.51 Unpacking python3-pkg-resources (39.0.1-2ubuntu0.1) ...
# #6 17.55 Selecting previously unselected package python3-setuptools.
# #6 17.55 Preparing to unpack .../43-python3-setuptools_39.0.1-2ubuntu0.1_all.deb ...
# #6 17.56 Unpacking python3-setuptools (39.0.1-2ubuntu0.1) ...
# #6 17.68 Setting up readline-common (7.0-3) ...
# #6 17.71 Setting up libicu60:amd64 (60.2-3ubuntu3.2) ...
# #6 17.72 Setting up mime-support (3.60ubuntu1) ...
# #6 17.74 Setting up libpng16-16:amd64 (1.6.34-1ubuntu0.18.04.2) ...
# #6 17.74 Setting up libjbig0:amd64 (2.1-3.1ubuntu0.18.04.1) ...
# #6 17.75 Setting up fonts-dejavu-core (2.37-1) ...
# #6 17.79 Setting up libreadline7:amd64 (7.0-3) ...
# #6 17.82 Setting up libpsl5:amd64 (0.19.1-5build1) ...
# #6 17.83 Setting up libelf1:amd64 (0.170-0.4ubuntu0.1) ...
# #6 17.84 Setting up nginx-common (1.14.0-0ubuntu1.11) ...
# #6 17.97 debconf: unable to initialize frontend: Dialog
# #6 17.97 debconf: (TERM is not set, so the dialog frontend is not usable.)
# #6 17.97 debconf: falling back to frontend: Readline
# #6 17.97 debconf: unable to initialize frontend: Readline
# #6 17.97 debconf: (Can't locate Term/ReadLine.pm in @INC (you may need to install the Term::ReadLine module) (@INC contains: /etc/perl /usr/local/lib/x86_64-linux-gnu/perl/5.26.1 /usr/local/share/perl/5.26.1 /usr/lib/x86_64-linux-gnu/perl5/5.26 /usr/share/perl5 /usr/lib/x86_64-linux-gnu/perl/5.26 /usr/share/perl/5.26 /usr/local/lib/site_perl /usr/lib/x86_64-linux-gnu/perl-base) at /usr/share/perl5/Debconf/FrontEnd/Readline.pm line 7.)
# #6 17.97 debconf: falling back to frontend: Teletype
# #6 18.17 Setting up libjpeg-turbo8:amd64 (1.5.2-0ubuntu5.18.04.6) ...
# #6 18.18 Setting up libgeoip1:amd64 (1.6.12-1) ...
# #6 18.19 Setting up libbsd0:amd64 (0.8.7-1ubuntu0.1) ...
# #6 18.20 Setting up ucf (3.0038) ...
# #6 18.28 debconf: unable to initialize frontend: Dialog
# #6 18.28 debconf: (TERM is not set, so the dialog frontend is not usable.)
# #6 18.28 debconf: falling back to frontend: Readline
# #6 18.28 debconf: unable to initialize frontend: Readline
# #6 18.28 debconf: (Can't locate Term/ReadLine.pm in @INC (you may need to install the Term::ReadLine module) (@INC contains: /etc/perl /usr/local/lib/x86_64-linux-gnu/perl/5.26.1 /usr/local/share/perl/5.26.1 /usr/lib/x86_64-linux-gnu/perl5/5.26 /usr/share/perl5 /usr/lib/x86_64-linux-gnu/perl/5.26 /usr/share/perl/5.26 /usr/local/lib/site_perl /usr/lib/x86_64-linux-gnu/perl-base) at /usr/share/perl5/Debconf/FrontEnd/Readline.pm line 7.)
# #6 18.28 debconf: falling back to frontend: Teletype
# #6 18.33 Setting up libxml2:amd64 (2.9.4+dfsg1-6.1ubuntu1.9) ...
# #6 18.34 Setting up libfreetype6:amd64 (2.8.1-2ubuntu2.2) ...
# #6 18.35 Setting up libxslt1.1:amd64 (1.1.29-5ubuntu0.3) ...
# #6 18.35 Setting up openssl (1.1.1-1ubuntu2.1~18.04.23) ...
# #6 18.36 Setting up wget (1.19.4-1ubuntu2.2) ...
# #6 18.37 Setting up libsqlite3-0:amd64 (3.22.0-1ubuntu0.7) ...
# #6 18.38 Setting up libnginx-mod-mail (1.14.0-0ubuntu1.11) ...
# #6 18.40 Setting up libnginx-mod-http-xslt-filter (1.14.0-0ubuntu1.11) ...
# #6 18.43 Setting up libxdmcp6:amd64 (1:1.1.2-3) ...
# #6 18.43 Setting up ca-certificates (20230311ubuntu0.18.04.1) ...
# #6 18.53 debconf: unable to initialize frontend: Dialog
# #6 18.53 debconf: (TERM is not set, so the dialog frontend is not usable.)
# #6 18.53 debconf: falling back to frontend: Readline
# #6 18.53 debconf: unable to initialize frontend: Readline
# #6 18.53 debconf: (Can't locate Term/ReadLine.pm in @INC (you may need to install the Term::ReadLine module) (@INC contains: /etc/perl /usr/local/lib/x86_64-linux-gnu/perl/5.26.1 /usr/local/share/perl/5.26.1 /usr/lib/x86_64-linux-gnu/perl5/5.26 /usr/share/perl5 /usr/lib/x86_64-linux-gnu/perl/5.26 /usr/share/perl/5.26 /usr/local/lib/site_perl /usr/lib/x86_64-linux-gnu/perl-base) at /usr/share/perl5/Debconf/FrontEnd/Readline.pm line 7.)
# #6 18.53 debconf: falling back to frontend: Teletype
# #6 19.01 Updating certificates in /etc/ssl/certs...
# #6 19.67 137 added, 0 removed; done.
# #6 19.70 Setting up libmnl0:amd64 (1.0.4-2) ...
# #6 19.71 Setting up libnginx-mod-http-geoip (1.14.0-0ubuntu1.11) ...
# #6 19.73 Setting up libx11-data (2:1.6.4-3ubuntu0.4) ...
# #6 19.74 Setting up libxau6:amd64 (1:1.0.8-1ubuntu1) ...
# #6 19.75 Setting up libmpdec2:amd64 (2.4.2-1ubuntu1) ...
# #6 19.76 Setting up libwebp6:amd64 (0.6.1-2ubuntu0.18.04.2) ...
# #6 19.76 Setting up libjpeg8:amd64 (8c-2ubuntu8) ...
# #6 19.77 Setting up python-pip-whl (9.0.1-2.3~ubuntu1.18.04.8) ...
# #6 19.78 Setting up libpython3.6-stdlib:amd64 (3.6.9-1~18.04ubuntu1.12) ...
# #6 19.79 Setting up fontconfig-config (2.12.6-0ubuntu2) ...
# #6 19.92 Setting up python3.6 (3.6.9-1~18.04ubuntu1.12) ...
# #6 20.87 Setting up libnginx-mod-stream (1.14.0-0ubuntu1.11) ...
# #6 20.89 Setting up libtiff5:amd64 (4.0.9-5ubuntu0.10) ...
# #6 20.90 Setting up iproute2 (4.15.0-2ubuntu1.3) ...
# #6 20.94 Setting up libxcb1:amd64 (1.13-2~ubuntu18.04) ...
# #6 20.95 Setting up libpython3-stdlib:amd64 (3.6.7-1~18.04) ...
# #6 20.96 Setting up libfontconfig1:amd64 (2.12.6-0ubuntu2) ...
# #6 20.97 Setting up python3 (3.6.7-1~18.04) ...
# #6 21.00 running python rtupdate hooks for python3.6...
# #6 21.00 running python post-rtupdate hooks for python3.6...
# #6 21.18 Setting up libx11-6:amd64 (2:1.6.4-3ubuntu0.4) ...
# #6 21.20 Setting up python3-pkg-resources (39.0.1-2ubuntu0.1) ...
# #6 21.49 Setting up libxpm4:amd64 (1:3.5.12-1ubuntu0.18.04.2) ...
# #6 21.50 Setting up python3-lib2to3 (3.6.9-1~18.04) ...
# #6 21.66 Setting up python3-distutils (3.6.9-1~18.04) ...
# #6 21.88 Setting up libgd3:amd64 (2.2.5-4ubuntu0.5) ...
# #6 21.88 Setting up python3-pip (9.0.1-2.3~ubuntu1.18.04.8) ...
# #6 22.14 Setting up python3-setuptools (39.0.1-2ubuntu0.1) ...
# #6 22.51 Setting up libnginx-mod-http-image-filter (1.14.0-0ubuntu1.11) ...
# #6 22.53 Setting up nginx-core (1.14.0-0ubuntu1.11) ...
# #6 22.67 invoke-rc.d: could not determine current runlevel
# #6 22.68 invoke-rc.d: policy-rc.d denied execution of start.
# #6 22.68 Setting up nginx (1.14.0-0ubuntu1.11) ...
# #6 22.69 Processing triggers for libc-bin (2.27-3ubuntu1.6) ...
# #6 22.71 Processing triggers for ca-certificates (20230311ubuntu0.18.04.1) ...
# #6 22.71 Updating certificates in /etc/ssl/certs...
# #6 23.14 0 added, 0 removed; done.
# #6 23.14 Running hooks in /etc/ca-certificates/update.d...
# #6 23.14 done.
# #6 DONE 24.0s
#
# #7 [3/7] RUN ln -s /usr/bin/python3 /usr/bin/python
# #7 DONE 0.3s
#
# #8 [4/7] RUN ln -s /usr/bin/pip3 /usr/bin/pip
# #8 DONE 0.3s
#
# #9 [5/7] RUN pip --no-cache-dir install numpy==1.16.2 scipy==1.2.1 scikit-learn==0.20.2 pandas flask gunicorn
# #9 1.624 Collecting numpy==1.16.2
# #9 2.962   Downloading https://files.pythonhosted.org/packages/35/d5/4f8410ac303e690144f0a0603c4b8fd3b986feb2749c435f7cdbb288f17e/numpy-1.16.2-cp36-cp36m-manylinux1_x86_64.whl (17.3MB)
# #9 3.924 Collecting scipy==1.2.1
# #9 4.791   Downloading https://files.pythonhosted.org/packages/7f/5f/c48860704092933bf1c4c1574a8de1ffd16bf4fde8bab190d747598844b2/scipy-1.2.1-cp36-cp36m-manylinux1_x86_64.whl (24.8MB)
# #9 6.004 Collecting scikit-learn==0.20.2
# #9 6.488   Downloading https://files.pythonhosted.org/packages/0d/3a/b92670f5c368c20329ecc4c255993fae7934564d485c3ed7ea7b8da7f741/scikit_learn-0.20.2-cp36-cp36m-manylinux1_x86_64.whl (5.4MB)
# #9 6.760 Collecting pandas
# #9 7.408   Downloading https://files.pythonhosted.org/packages/c3/e2/00cacecafbab071c787019f00ad84ca3185952f6bb9bca9550ed83870d4d/pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5MB)
# #9 7.940 Collecting flask
# #9 8.046   Downloading https://files.pythonhosted.org/packages/cd/77/59df23681f4fd19b7cbbb5e92484d46ad587554f5d490f33ef907e456132/Flask-2.0.3-py3-none-any.whl (95kB)
# #9 8.072 Collecting gunicorn
# #9 8.208   Downloading https://files.pythonhosted.org/packages/0e/2a/c3a878eccb100ccddf45c50b6b8db8cf3301a6adede6e31d48e8531cab13/gunicorn-21.2.0-py3-none-any.whl (80kB)
# #9 8.285 Collecting pytz>=2017.2 (from pandas)
# #9 8.586   Downloading https://files.pythonhosted.org/packages/9c/3d/a121f284241f08268b21359bd425f7d4825cffc5ac5cd0e1b3d82ffd2b10/pytz-2024.1-py2.py3-none-any.whl (505kB)
# #9 8.705 Collecting python-dateutil>=2.7.3 (from pandas)
# #9 8.797   Downloading https://files.pythonhosted.org/packages/ec/57/56b9bcc3c9c6a792fcbaf139543cee77261f3651ca9da0c93f5c1221264b/python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229kB)
# #9 8.828 Collecting Jinja2>=3.0 (from flask)
# #9 8.938   Downloading https://files.pythonhosted.org/packages/20/9a/e5d9ec41927401e41aea8af6d16e78b5e612bca4699d417f646a9610a076/Jinja2-3.0.3-py3-none-any.whl (133kB)
# #9 8.963 Collecting Werkzeug>=2.0 (from flask)
# #9 9.135   Downloading https://files.pythonhosted.org/packages/f4/f3/22afbdb20cc4654b10c98043414a14057cd27fdba9d4ae61cea596000ba2/Werkzeug-2.0.3-py3-none-any.whl (289kB)
# #9 9.176 Collecting click>=7.1.2 (from flask)
# #9 9.331   Downloading https://files.pythonhosted.org/packages/4a/a8/0b2ced25639fb20cc1c9784de90a8c25f9504a7f18cd8b5397bd61696d7d/click-8.0.4-py3-none-any.whl (97kB)
# #9 9.352 Collecting itsdangerous>=2.0 (from flask)
# #9 9.430   Downloading https://files.pythonhosted.org/packages/9c/96/26f935afba9cd6140216da5add223a0c465b99d0f112b68a4ca426441019/itsdangerous-2.0.1-py3-none-any.whl
# #9 9.443 Collecting importlib-metadata; python_version < "3.8" (from gunicorn)
# #9 9.668   Downloading https://files.pythonhosted.org/packages/a0/a1/b153a0a4caf7a7e3f15c2cd56c7702e2cf3d89b1b359d1f1c5e59d68f4ce/importlib_metadata-4.8.3-py3-none-any.whl
# #9 9.737 Collecting packaging (from gunicorn)
# #9 9.838   Downloading https://files.pythonhosted.org/packages/05/8e/8de486cbd03baba4deef4142bd643a3e7bbe954a784dc1bb17142572d127/packaging-21.3-py3-none-any.whl (40kB)
# #9 9.857 Collecting six>=1.5 (from python-dateutil>=2.7.3->pandas)
# #9 9.969   Downloading https://files.pythonhosted.org/packages/d9/5a/e7c31adbe875f2abbb91bd84cf2dc52d792b5a01506781dbcf25c91daf11/six-1.16.0-py2.py3-none-any.whl
# #9 9.995 Collecting MarkupSafe>=2.0 (from Jinja2>=3.0->flask)
# #9 10.35   Downloading https://files.pythonhosted.org/packages/fc/d6/57f9a97e56447a1e340f8574836d3b636e2c14de304943836bd645fa9c7e/MarkupSafe-2.0.1-cp36-cp36m-manylinux1_x86_64.whl
# #9 10.36 Collecting dataclasses; python_version < "3.7" (from Werkzeug>=2.0->flask)
# #9 10.44   Downloading https://files.pythonhosted.org/packages/fe/ca/75fac5856ab5cfa51bbbcefa250182e50441074fdc3f803f6e76451fab43/dataclasses-0.8-py3-none-any.whl
# #9 10.47 Collecting zipp>=0.5 (from importlib-metadata; python_version < "3.8"->gunicorn)
# #9 10.59   Downloading https://files.pythonhosted.org/packages/bd/df/d4a4974a3e3957fd1c1fa3082366d7fff6e428ddb55f074bf64876f8e8ad/zipp-3.6.0-py3-none-any.whl
# #9 10.62 Collecting typing-extensions>=3.6.4; python_version < "3.8" (from importlib-metadata; python_version < "3.8"->gunicorn)
# #9 10.72   Downloading https://files.pythonhosted.org/packages/45/6b/44f7f8f1e110027cf88956b59f2fad776cca7e1704396d043f89effd3a0e/typing_extensions-4.1.1-py3-none-any.whl
# #9 10.74 Collecting pyparsing!=3.0.5,>=2.0.2 (from packaging->gunicorn)
# #9 10.88   Downloading https://files.pythonhosted.org/packages/e5/0c/0e3c05b1c87bb6a1c76d281b0f35e78d2d80ac91b5f8f524cebf77f51049/pyparsing-3.1.4-py3-none-any.whl (104kB)
# #9 10.90 Installing collected packages: numpy, scipy, scikit-learn, pytz, six, python-dateutil, pandas, MarkupSafe, Jinja2, dataclasses, Werkzeug, zipp, typing-extensions, importlib-metadata, click, itsdangerous, flask, pyparsing, packaging, gunicorn
# #9 21.68 Successfully installed Jinja2-3.0.3 MarkupSafe-2.0.1 Werkzeug-2.0.3 click-8.0.4 dataclasses-0.8 flask-2.0.3 gunicorn-21.2.0 importlib-metadata-4.8.3 itsdangerous-2.0.1 numpy-1.16.2 packaging-21.3 pandas-1.1.5 pyparsing-3.1.4 python-dateutil-2.9.0.post0 pytz-2024.1 scikit-learn-0.20.2 scipy-1.2.1 six-1.16.0 typing-extensions-4.1.1 zipp-3.6.0
# #9 DONE 23.1s
#
# #10 [6/7] COPY decision_trees /opt/program
# #10 DONE 0.0s
#
# #11 [7/7] WORKDIR /opt/program
# #11 DONE 0.0s
#
# #12 exporting to image
# #12 exporting layers
# #12 exporting layers 2.2s done
# #12 writing image sha256:a47a6ec9aae1dae147954cf72e3bf0c0d14fb8db14ab1b5b0a2e478f5573d153 done
# #12 naming to docker.io/library/sagemaker-decision-trees done
# #12 DONE 2.2s
# The push refers to repository [034362035459.dkr.ecr.us-east-2.amazonaws.com/sagemaker-decision-trees]
# 5f70bf18a086: Preparing
# 5ac80cdeb6a7: Preparing
# 92f5f20e3af3: Preparing
# bdcbc27af591: Preparing
# f90608acc66a: Preparing
# b0f540da9d8e: Preparing
# 548a79621a42: Preparing
# b0f540da9d8e: Waiting
# 548a79621a42: Waiting
# 5ac80cdeb6a7: Pushed
# f90608acc66a: Pushed
# bdcbc27af591: Pushed
# 5f70bf18a086: Pushed
# 548a79621a42: Pushed
# b0f540da9d8e: Pushed
# 92f5f20e3af3: Pushed
# latest: digest: sha256:1637835fbc193e71e19338edb9556295d86331536d02261785b0cfdfdf2b461e size: 1781

# %%
# S3 prefix
prefix = "winequality-red"

# Define IAM role
import boto3
import re

import os
import numpy as np
import pandas as pd
from sagemaker import get_execution_role

role = get_execution_role()
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %%
import sagemaker as sage
from time import gmtime, strftime

sess = sage.Session()

# %%
WORK_DIRECTORY = "data"

data_location = sess.upload_data(WORK_DIRECTORY, key_prefix=prefix)

# %%
from sagemaker.sklearn import SKLearn

sk_estimator = SKLearn(
    entry_point="container/decision_trees/predictor.py",
    role=role,
    instance_count=1,
    instance_type="ml.c5.xlarge",
    py_version="py3",
    framework_version="1.0-1",
    hyperparameters={"estimators": 20},
)

# %%
sk_estimator.fit(data_location)
# Out:
# INFO:sagemaker:Creating training-job with name: sagemaker-scikit-learn-2024-08-31-22-23-31-647
# 2024-08-31 22:23:36 Starting - Starting the training job...
# 2024-08-31 22:23:50 Starting - Preparing the instances for training...
# 2024-08-31 22:24:24 Downloading - Downloading the training image.....2024-08-31 22:25:18,722 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 2024-08-31 22:25:18,726 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-08-31 22:25:18,728 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2024-08-31 22:25:18,744 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2024-08-31 22:25:18,989 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-08-31 22:25:18,992 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2024-08-31 22:25:19,009 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-08-31 22:25:19,012 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2024-08-31 22:25:19,030 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-08-31 22:25:19,033 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2024-08-31 22:25:19,047 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "current_instance_group": "homogeneousCluster",
#     "current_instance_group_hosts": [
#         "algo-1"
#     ],
#     "current_instance_type": "ml.c5.xlarge",
#     "distribution_hosts": [],
#     "distribution_instance_groups": [],
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "estimators": 20
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "instance_groups": [
#         "homogeneousCluster"
#     ],
#     "instance_groups_dict": {
#         "homogeneousCluster": {
#             "instance_group_name": "homogeneousCluster",
#             "instance_type": "ml.c5.xlarge",
#             "hosts": [
#                 "algo-1"
#             ]
#         }
#     },
#     "is_hetero": false,
#     "is_master": true,
#     "is_modelparallel_enabled": null,
#     "is_smddpmprun_installed": false,
#     "is_smddprun_installed": false,
#     "job_name": "sagemaker-scikit-learn-2024-08-31-22-23-31-647",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-2-034362035459/sagemaker-scikit-learn-2024-08-31-22-23-31-647/source/sourcedir.tar.gz",
#     "module_name": "predictor",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "num_neurons": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.c5.xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.c5.xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "predictor.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"estimators":20}
# SM_USER_ENTRY_POINT=predictor.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.c5.xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.c5.xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_CURRENT_INSTANCE_TYPE=ml.c5.xlarge
# SM_CURRENT_INSTANCE_GROUP=homogeneousCluster
# SM_CURRENT_INSTANCE_GROUP_HOSTS=["algo-1"]
# SM_INSTANCE_GROUPS=["homogeneousCluster"]
# SM_INSTANCE_GROUPS_DICT={"homogeneousCluster":{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.c5.xlarge"}}
# SM_DISTRIBUTION_INSTANCE_GROUPS=[]
# SM_IS_HETERO=false
# SM_MODULE_NAME=predictor
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_NUM_NEURONS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-2-034362035459/sagemaker-scikit-learn-2024-08-31-22-23-31-647/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","current_instance_group":"homogeneousCluster","current_instance_group_hosts":["algo-1"],"current_instance_type":"ml.c5.xlarge","distribution_hosts":[],"distribution_instance_groups":[],"framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"estimators":20},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","instance_groups":["homogeneousCluster"],"instance_groups_dict":{"homogeneousCluster":{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.c5.xlarge"}},"is_hetero":false,"is_master":true,"is_modelparallel_enabled":null,"is_smddpmprun_installed":false,"is_smddprun_installed":false,"job_name":"sagemaker-scikit-learn-2024-08-31-22-23-31-647","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-2-034362035459/sagemaker-scikit-learn-2024-08-31-22-23-31-647/source/sourcedir.tar.gz","module_name":"predictor","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"num_neurons":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.c5.xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.c5.xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"predictor.py"}
# SM_USER_ARGS=["--estimators","20"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_ESTIMATORS=20
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python38.zip:/miniconda3/lib/python3.8:/miniconda3/lib/python3.8/lib-dynload:/miniconda3/lib/python3.8/site-packages
# Invoking script with the following command:
# /miniconda3/bin/python predictor.py --estimators 20
# 2024-08-31 22:25:19,048 sagemaker-training-toolkit INFO     Exceptions not imported for SageMaker Debugger as it is not installed.
# 2024-08-31 22:25:19,048 sagemaker-training-toolkit INFO     Exceptions not imported for SageMaker TF as Tensorflow is not installed.
# 2024-08-31 22:25:19,590 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2024-08-31 22:25:33 Training - Training image download completed. Training in progress.
# 2024-08-31 22:25:33 Uploading - Uploading generated training model
# 2024-08-31 22:25:33 Completed - Training job completed
# Training seconds: 84
# Billable seconds: 84

# %%
predictor = sk_estimator.deploy(1, "ml.m4.xlarge")
# Out:
# INFO:sagemaker:Creating model with name: sagemaker-scikit-learn-2024-08-31-22-27-39-230
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 predictor = sk_estimator.deploy(1, "ml.m4.xlarge")
#
# File ~/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/sagemaker/estimator.py:1684, in EstimatorBase.deploy(self, initial_instance_count, instance_type, serializer, deserializer, accelerator_type, endpoint_name, use_compiled_model, wait, model_name, kms_key, data_capture_config, tags, serverless_inference_config, async_inference_config, volume_size, model_data_download_timeout, container_startup_health_check_timeout, inference_recommendation_id, explainer_config, **kwargs)
#    1678 model.name = model_name
#    1680 tags = update_inference_tags_with_jumpstart_training_tags(
#    1681     inference_tags=format_tags(tags), training_tags=self.tags
#    1682 )
# -> 1684 return model.deploy(
#    1685     instance_type=instance_type,
#    1686     initial_instance_count=initial_instance_count,
#    1687     serializer=serializer,
#    1688     deserializer=deserializer,
#    1689     accelerator_type=accelerator_type,
#    1690     endpoint_name=endpoint_name,
#    1691     tags=tags or self.tags,
#    1692     wait=wait,
#    1693     kms_key=kms_key,
#    1694     data_capture_config=data_capture_config,
#    1695     serverless_inference_config=serverless_inference_config,
#    1696     async_inference_config=async_inference_config,
#    1697     explainer_config=explainer_config,
#    1698     volume_size=volume_size,
#    1699     model_data_download_timeout=model_data_download_timeout,
#    1700     container_startup_health_check_timeout=container_startup_health_check_timeout,
#    1701     inference_recommendation_id=inference_recommendation_id,
#    1702 )
#
# File ~/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/sagemaker/model.py:1698, in Model.deploy(self, initial_instance_count, instance_type, serializer, deserializer, accelerator_type, endpoint_name, tags, kms_key, wait, data_capture_config, async_inference_config, serverless_inference_config, volume_size, model_data_download_timeout, container_startup_health_check_timeout, inference_recommendation_id, explainer_config, accept_eula, endpoint_logging, resources, endpoint_type, managed_instance_scaling, inference_component_name, routing_config, model_reference_arn, **kwargs)
#    1695     return None
#    1697 else:  # existing single model endpoint path
# -> 1698     self._create_sagemaker_model(
#    1699         instance_type=instance_type,
#    1700         accelerator_type=accelerator_type,
#    1701         tags=tags,
#    1702         serverless_inference_config=serverless_inference_config,
#    1703         accept_eula=accept_eula,
#    1704         model_reference_arn=model_reference_arn,
#    1705     )
#    1706     serverless_inference_config_dict = (
#    1707         serverless_inference_config._to_request_dict() if is_serverless else None
#    1708     )
#    1709     production_variant = sagemaker.production_variant(
#    1710         self.name,
#    1711         instance_type,
#    (...)
#    1718         routing_config=routing_config,
#    1719     )
#
# File ~/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/sagemaker/model.py:980, in Model._create_sagemaker_model(self, instance_type, accelerator_type, tags, serverless_inference_config, accept_eula, model_reference_arn)
#     966 self.env = resolve_nested_dict_value_from_config(
#     967     self.env,
#     968     ["Environment"],
#     969     MODEL_CONTAINERS_PATH,
#     970     sagemaker_session=self.sagemaker_session,
#     971 )
#     972 create_model_args = dict(
#     973     name=self.name,
#     974     role=self.role,
#    (...)
#     978     tags=format_tags(tags),
#     979 )
# --> 980 self.sagemaker_session.create_model(**create_model_args)
#
# File ~/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/sagemaker/session.py:3982, in Session.create_model(self, name, role, container_defs, vpc_config, enable_network_isolation, primary_container, tags)
#    3979         else:
#    3980             raise
# -> 3982 self._intercept_create_request(create_model_request, submit, self.create_model.__name__)
#    3983 return name
#
# File ~/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/sagemaker/session.py:6520, in Session._intercept_create_request(self, request, create, func_name)
#    6503 def _intercept_create_request(
#    6504     self,
#    6505     request: typing.Dict,
#    (...)
#    6508     # pylint: disable=unused-argument
#    6509 ):
#    6510     """This function intercepts the create job request.
#    6511
#    6512     PipelineSession inherits this Session class and will override
#    (...)
#    6518         func_name (str): the name of the function needed intercepting
#    6519     """
# -> 6520     return create(request)
#
# File ~/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/sagemaker/session.py:3970, in Session.create_model.<locals>.submit(request)
#    3968 logger.debug("CreateModel request: %s", json.dumps(request, indent=4))
#    3969 try:
# -> 3970     self.sagemaker_client.create_model(**request)
#    3971 except ClientError as e:
#    3972     error_code = e.response["Error"]["Code"]
#
# File ~/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/botocore/client.py:569, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     565     raise TypeError(
#     566         f"{py_operation_name}() only accepts keyword arguments."
#     567     )
#     568 # The "self" in this scope is referring to the BaseClient.
# --> 569 return self._make_api_call(operation_name, kwargs)
#
# File ~/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/botocore/client.py:1023, in BaseClient._make_api_call(self, operation_name, api_params)
#    1019     error_code = error_info.get("QueryErrorCode") or error_info.get(
#    1020         "Code"
#    1021     )
#    1022     error_class = self.exceptions.from_code(error_code)
# -> 1023     raise error_class(parsed_response, operation_name)
#    1024 else:
#    1025     return parsed_response
#
# ClientError: An error occurred (ValidationException) when calling the CreateModel operation: Could not find model data at s3://sagemaker-us-east-2-034362035459/sagemaker-scikit-learn-2024-08-31-22-23-31-647/output/model.tar.gz.
